# %% [markdown]
# <figure>
#   <IMG SRC="https://upload.wikimedia.org/wikipedia/commons/thumb/d/d5/Fachhochschule_Südwestfalen_20xx_logo.svg/320px-Fachhochschule_Südwestfalen_20xx_logo.svg.png" WIDTH=250 ALIGN="right">
# </figure>
#
# # Einführung in die Programmierung
# ### Winterersemester 2025/26
# Prof. Dr. Stefan Goetze

# %% [markdown]
# ### 4. Umgang mit Texten
#
# #### 4.1. Buchstaben und Ziffern in einem Text abzählen
#
# Die folgende Abbildung 1 visualisert, wie Zeichen oder Wörter in einem Text gezählt werden können.
#
# <center>
#
# ![Zustandsdiagramme zur Wort- und Zahlenerkennung](https://raw.githubusercontent.com/fhswf/EinfProg/refs/heads/main/p3/figures/zustandsdiagramm_wort_zahlerkennung.png)<br>
# Abbildung 1.: Zustandsdiagramme zur Wort- und Zahlenerkennung
#
# </center>
#
# * Geben ist das folgende Fuktion `count_characters(filename)` die einen Text einliest, ausgibt und die Anzahl der Klein- und Großbuchstaben ermittelt wird.
#
# Überprüfen Sie dessen Funktionsweise !
# * Erweitern Sie das Programm so, daß auch Ziffern abgezählt werden können (Nutzen Sie dafür z.B. die [`isdigit()`](https://docs.python.org/3/library/stdtypes.html#str.isdigit) Funktion).
# * Ändern Sie das Programm nun so, daß die Unterscheidung zwischen Klein- und Großbuchstaben
# entfällt und nur Buchstaben (Nutzen Sie dafür z.B. die [`isalpha()`](https://docs.python.org/3/library/stdtypes.html#str.isalpha) Funktion) und Ziffern abgezählt werden. Die beiden hier gegebenen Links verlinken zu einer kompletteren Liste von [String-Analyse-Funktionen](https://docs.python.org/3/library/stdtypes.html#text-and-binary-sequence-type-methods-summary), die ggf. einen Blick wert sind.

# %%
# Buchstaben und Ziffern in einem Text abzählen.

def count_characters(filename):
    # Öffnen der Datei im Lesemodus
    with open(filename, 'r', encoding='utf-8') as file:
        text = file.read()

    # Ausgabe des Textes
    print("Folgender Text wurde eingelesen:\n")
    print(text)
    print("\n")

    # Zähler für Klein- und Großbuchstaben
    lowerCaseCharacters = 0
    upperCaseCharacters = 0
    
    # Zähler für Ziffern und alle Buchstaben
    # YOUR CODE HERE
    raise NotImplementedError()

    
    # Durchlaufen des Textes und Zählen der Buchstaben
    for character in text:
        if character.islower():
            lowerCaseCharacters += 1
        elif character.isupper():
            upperCaseCharacters += 1
        # YOUR CODE HERE
        raise NotImplementedError()

    # Ausgabe der Ergebnisse
    print(f"Anzahl der Kleinbuchstaben: {lowerCaseCharacters:3}")
    print(f"Anzahl der Großbuchstaben:  {upperCaseCharacters:3}")
    # YOUR CODE HERE
    raise NotImplementedError()


# Aufruf der Funktion
try:
    filename = 'text_1.txt'
    count_characters(filename)
except FileNotFoundError:
    print(f"Fehler: Die Datei '{filename}' wurde nicht gefunden.")
except PermissionError:
    print(f"Fehler: Leserecht für die Datei '{filename}' fehlt.")
except Exception as e:
    print("Unerwarteter Fehler")
    print(str(e))

# %% [markdown]
# #### 4.2. Wörter in einem Text abzählen
# Das unter [Abschnitt 4.1](#4.1.-buchstaben-und-ziffern-in-einem-text-abzählen) entwickelte Programm soll nun so abgeändert werden, daß die **Wörter** im Eingabetext abgezählt und deren Anzahl ausgegeben werden.
#
# Die Analyse kann wie folgt durchgeführt werden:<br>
# Das augenblicklich betrachtete Zeichen gehört entweder zu einem Wort oder zu einem Zwischenraum (Folge von Leerzeichen und/oder Tabulatoren).<br>
# Jeder der beiden Zustände wird in einer Zustandsvariablen zustand codiert, zum Beispiel
# * EMPTY: zustand=0,
# * WORD : zustand=1.
#
# In jedem Schritt (das heißt beim jeweils nächsten zu betrachtenden Zeichen) wird überprüft, ob eine Zustandsänderung stattfindet (siehe Abbildung 1). Beim Zustandsübergang EMPTY → WORD wird der Wortzähler erhöht.
# Es gibt zwar mehrere Zustände, die Implementierung benötigt jedoch nur eine einzige Zustandsvariable, da die Zustände numeriert sind.<br>
# Zur Klassifizierung der einzelnen Zeichen bietet Python Klassifizierungsfunktionen an. Ein Teil davon ist in Abbildung 2 dargestellt.
#
# <center>
#
# ![Klassifizierungsfunktionen](https://raw.githubusercontent.com/fhswf/EinfProg/refs/heads/main/p3/figures/character-klassifizierungsmethoden.png)<br>
# Abbildung 2.: Hierarchie der Zeichenklassen und der Klassifizierungsfunktionen in Python (Auszug).
#
# </center>
#
# Die Funktion soll die Anzahl der Wörter in der Datei, deren Name übergeben wird, zurückgeben.
#
# **<u>Tipp</u>**<br>
# Der Wortzähler wird hochgezählt, wenn der Anfang eines Wortes erkannt wird.<br>
# Zu Testzwecken kann der Buchstabe, bei dem ein Wortanfang erkannt wird, ausgegeben und die Liste mit dem Inhalt der Datei verglichen werden.

# %%
# Wörter in einem Text abzählen
EMPTY = 0
WORD = 1
def count_words(filename):   
    state = EMPTY
    words = 0

    # YOUR CODE HERE
    raise NotImplementedError()
    return words

# Aufruf der Funktion
try:
    filename = 'text_1.txt'
    print(f"'{filename}' enthält {count_words(filename)} Wörter")
except FileNotFoundError:
    print(f"Fehler: Die Datei '{filename}' wurde nicht gefunden.")
except PermissionError:
    print(f"Fehler: Leserecht für die Datei '{filename}' fehlt.")
except Exception as e:
    print("Unerwarteter Fehler")
    print(str(e))

# %%
# (Versteckter) Test der Funktion "Wörter in einem Text abzählen"
# Verläuft der Test erfolgreich, werden keine Meldungen ausgegeben.

# %% [markdown]
# ### 4.3. Wörter und Zahlen in einem Text abzählen
# Das unter [Wörter in einem Text abzählen](#42-wörter-in-einem-text-abzählen) entwickelte Programm soll nun so abgeändert werden, daß zusätzlich Zahlen im Eingabetext erkannt, abgezählt und auch deren Anzahl ausgegeben wird. Dazu ist gemäß Abbildung 1a ein weiterer Zustand NUMBER einzufügen und die zusätzlichen Übergänge zu implementieren.<br>
#
# Diese Funktion ermittelt $2$ Werte. Um diese zurück geben zu können, implementieren Sie die Rückgabe als Liste:<br>
# `return (words, numbers)`
#
# Erweitern Sie das Programm indem Sie prüfen, ob in einer Buchstabenfolge eine Ziffer oder in einer Ziffernfolge ein Buchstabe auftritt (Abbildung 1b). In diesem Fall soll das Programm mit<br>
# `raise ValueError("Fehlermeldung")`<br>
# einen Fehler mit einer zu dem gefundenen Fehler passenden Fehlermeldung werfen.<br>
#
# * Verwenden Sie für die Auszählung wieder die Datei `text_1.txt`. Überprüfen Sie das Ergebnis Ihrer Auszählung !
# * Die Datei `text_4_3b.txt` enthält eine Ziffer in einem Wort. Überprüfen Sie, dass der Fehler gefunden wird.
# * Die Datei `text_4_3c.txt` enthält einen Buchstaben in einer Zahl. Überprüfen Sie, dass der Fehler gefunden wird.

# %%
# Wörter und Zahlen in einem Text abzählen
EMPTY = 0
WORD = 1
NUMBER = 2
def test_count_words_and_numbers(filename):
    state = EMPTY
    words = 0
    numbers = 0

    # YOUR CODE HERE
    raise NotImplementedError()
    return (words, numbers)


# Aufruf der Funktion
try:
    filename = 'text_1.txt'
    #filename = 'text_4_3a.txt'
    #filename = 'text_4_3b.txt'
    #filename = 'text_4_3c.txt'
    result = test_count_words_and_numbers(filename)
    print(f"'{filename}' hat {result[0]:3} Wörter und {result[1]:3} Zahlen")
except FileNotFoundError:
    print(f"Fehler: Die Datei '{filename}' wurde nicht gefunden.")
except PermissionError:
    print(f"Fehler: Leserecht für die Datei '{filename}' fehlt.")
# ValueError wird im Fall Buchstabe in Zahl oder Ziffer in Wort absichtlich geworfen
# Muss vor Exception gefangen und weiter geworfen werden.
except ValueError as e:
    print(f"Fehler in der Datei: {str(e)}")
except Exception as e:
    print("Unerwarteter Fehler")
    print(str(e))

# %%
# (Versteckter) Test der Funktion "Wörter in einem Text abzählen"
# Verläuft der Test erfolgreich, werden keine Meldungen ausgegeben.
