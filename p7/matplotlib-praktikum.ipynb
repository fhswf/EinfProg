# %% [markdown]
# <figure>
#   <IMG SRC="https://upload.wikimedia.org/wikipedia/commons/thumb/d/d5/Fachhochschule_Südwestfalen_20xx_logo.svg/320px-Fachhochschule_Südwestfalen_20xx_logo.svg.png" WIDTH=250 ALIGN="right">
# </figure>
#
# # Einführung in die Programmierung
# ### Winterersemester 2025/26
# Prof. Dr. Stefan Goetze

# %% [markdown]
# # Visualisierung (matplotlib)
#
# ## Matplotlib importieren
#
# So wie wir die Kurzform `np` für NumPy (oder `pd` für Pandas) verwenden, nutzen wir auch für Matplotlib einige Standard-Kurzformen:

# %%
import matplotlib.pyplot as plt  # for plotting
import numpy as np  # for numerical operations

# %% [markdown]
# ## Aufgabe 1 – Sinussignal erzeugen
#
# Erzeugen Sie ein Sinussignal:
#
# $$
# x(t) = \sin(2 \pi f t).
# $$
#
# mit einer Länge von $0,25$ Sekunden und einer Frequenz von $f = 250$ Hz.
#
# Hinweis: Erzeugen Sie dazu zuerst einen Zeitvektor `t` mit einer Abtastrate (*engl. sampling rate*) von $f_s=44.100$ Hz, also mit $44.100$ Punkten pro Sekunde. Sie können dazu die NumPy Funktion [`np.arange()`](https://numpy.org/doc/stable/reference/generated/numpy.arange.html) oder alternativ die Funktion [`np.linspace()`](https://numpy.org/doc/stable/reference/generated/numpy.linspace.html) nutzen. Für die Konstante $\pi$ können Sie `np.pi` verwenden. Danach können Sie den Sinus mit der Numpy Funktion [`np.sin()`](https://numpy.org/doc/stable/reference/generated/numpy.sin.html) erzeugen.

# %%
## Create a sine signal x(t) = sin(2 pi f t) 
 
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# Stellen Sie den erzeugten Sinus mittels [`plt.plot()`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html) dar. Fügen Sie auch $x$- und $y$-Achsenbeschriftungen sowie einen Titel hinzu (hierzu können die Methoden [`plt.ylabel()`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.xlabel.html), [`plt.ylabel()`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.ylabel.html) und [`plt.title()`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.title.html) verwendet werden.

# %%
# plot the created sine signal

# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# `IPython.display.Audio()` erzeugt ein Player-Objekt, mit dem das Signal wiedergegeben werden kann (entweder eine Variable oder eine Datei). Da wir die Variable `x` als Eingabeargument verwenden möchten, müssen wir auch die Abtastfrequenz $f_s$ (Variable `rate=`) angeben.

# %%
import IPython.display as ipd
ipd.Audio(x/10,rate=fs)           # dividing the level by 10 ensures that playback is not too loud

# %% [markdown]
# ### Aufgabe 1.1
#
# Experiementieren Sie mit der Frequenz $f$. Was *hören* Sie? Macht es einen Unterschied, ob Sie die Funktion [`np.sin()`](https://numpy.org/doc/stable/reference/generated/numpy.sin.html) oder [`np.cos()`](https://numpy.org/doc/stable/reference/generated/numpy.cos.html) verwenden?

# %%
# Your code to experiment with different frequencies and sine/cosine functions can go here.

# %% [markdown]
# ## Aufgabe 2 – Überlagerung (Addition) von Sinussignalen
#
# Erzeugen Sie nun $2$ Sinussignale
#
# \begin{align}
# x_1(t) &= \sin(2 \pi f_1 t) \text{  und} \\
# x_2(t) &= \sin(2 \pi f_2 t)
# \end{align}
#
# mit den Frequenzen $f_1=60$ Hz und $f_2=200$ Hz (jeweils der Länge $0.5\,\mathrm{sec}$) und addieren Sie diese. Stellen Sie die Signale sowie die Addition der Signale unter Verwendung des [`plt.subplot()`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplot.html) Befehls dar.
#
# Sie können im [`plt.plot()`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html) Befehl mit dem Argument `label="..."` eine Bezeichnung (String) für die jeweilige Kurve festlegen, die Sie dann mit dem Befehl [`plt.legend()`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.legend.html) anzeigen können. Probieren Sie dies aus.
#
# Was hören Sie?

# %%
# create and plot two sine signals and their sum

StopTime = 0.5                   # length in seconds
t = np.arange(0,StopTime,dt)     # time vector in seconds

# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# ## Aufgabe 3 – Umgang mit Audiodateien
#
# Der Befehl `curl` lädt die Datei `https://staffwww.dcs.shef.ac.uk/people/S.Goetze/sound/speech.wav` auf die Festplatte herunter.

# %%
# download wave file
# !curl https://staffwww.dcs.shef.ac.uk/people/S.Goetze/sound/speech.wav -o speech.wav

# %% [markdown]
# Die Funktion `sf.read(...)` lädt den Inhalt der WAVE-Datei in den Speicher. Die Variable `s` enthält den Sprachsignalvektor $s[k]$ und die Variable `fs` enthält die Abtastrate, auch Abtastfrequenz genannt, $f_s$, d. h. die Anzahl der diskreten Abtastwerte eines Signals pro Sekunde.

# %%
# remove the comment character (#) in case you need to install this library.
#!pip install soundfile

# %%
# remove the comment character (#) in case you need to install this library.
#!pip install soundfile

import soundfile as sf
s_file_name = 'speech.wav'
s,fs = sf.read(s_file_name)

print(s.shape) # this prints the dimension (length) of the vector s 
               # (not necessary in the following but to get an idea about the size (shape))

# %% [markdown]
# Stellen Sie das Signal $s[k]$ mit dem Befehl `plot()` aus der Bibliothek `matplotlib.pyplot` dar. Stellen Sie das Audiosiganl einmal einfach Sample für Sample dar und einmal über die Zeit $t$, erzeugen Sie also einen Zeitvektor `t` für die Darstellung.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# ## Blockverarbeitung (Aufgabe 4)
#
# Zur Veranschaulichung der Blockverarbeitung haben wir zunächst einen Abschnitt von $4096$ Abtastwerten ausgeschnitten, beginnend bei $10$ Sekunden, d. h. ab Abtastwert $80.000$ bei einer Abtastrate von $f_s = 8000$ Hz. Dieser Abschnitt ist im oberen Diagramm rot markiert und im unteren Diagramm der folgenden Abbildung wiederholt.
#
# Wie in den vorherigen Abschnitt laden wir zunächst eine WAV-Datei $s[k]$ mit dem Befehl `curl` herunter und speichern sie in einer Variablen. Bitte beachten Sie, dass der untenstehende `curl`-Befehl im Vergleich zu den vorherigen Übungsblättern leicht modifiziert wurde, da er einen Variablennamen in geschweiften Klammern ({}) verwendet. Wir können den Dateinamen später im Befehl `sf.read()` wiederverwenden.

# %%
# download speech and noise example files
s_file_name = 'speech_8kHz_murder.wav'
# !curl https://staffwww.dcs.shef.ac.uk/people/S.Goetze/sound/{s_file_name} -o {s_file_name}

# %%
# load speech wave into variable
s, fs = sf.read(s_file_name)

print('File "' + s_file_name + '" loaded. Its sampling rate is ' + str(fs) + ' Hz.')

# listen to the sound file (if you want)
ipd.Audio(s, rate=fs)

# %%
# lets cut out a piece of the data and cisualise it
start_sample = int(10*fs);                   # start at 10 sec
#print(start_sample)
no_of_samples = 4096;                        # no of samples we want to cut out    
end_sample   = start_sample + no_of_samples; # last sample to be cut out
sample_vec = np.linspace(start_sample, end_sample, no_of_samples)
x1=s[start_sample:end_sample];

plt.figure(figsize=(8,5))
plt.subplot(2,1,1)
plt.plot(np.arange(0,len(s)),s)
plt.ylabel('$x_1[k]$')
plt.plot(sample_vec,x1,'r')
plt.subplot(2,1,2)
plt.plot(sample_vec,x1,'r')
plt.xlabel('$k$')
plt.ylabel('$x_1$[' + str(start_sample) + '...' + str(end_sample) + ']')
plt.title('$x_1[k]$ for ' + str(len(x1)) + ' samples between ' 
          + str(start_sample) + ' to ' + str(end_sample) + 
          ' ($f_s$=' + str(fs) +')')
plt.tight_layout() # this allowes for some space for the title text.

# %%
# listen to the short cut-out
ipd.Audio(x1, rate=fs)

# %% [markdown]
# Wie bei Sprachverarbeitungsalgorithmen üblich, wird eine Blockverarbeitung (Gleitfensterverfahren) angewendet. Teilen Sie dazu das oben rot dargestellte Signal in Blöcke der Länge $L_w = 512$ Samples und stellen Sie diese in einzelnen Subplots dar.

# %%
# lets cut out a piece of the data
Lw   = 512                    # frame length
Lov  = 1                      # frame overlap factor 
Lhop = int(np.round(Lw/Lov)); # frame hop size

# YOUR CODE HERE
raise NotImplementedError()
